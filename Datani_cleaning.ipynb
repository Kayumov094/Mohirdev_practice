# %% [markdown]
# <a href="https://colab.research.google.com/github/Kayumov094/Datani_tozalash/blob/main/Datani_tozalash_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mukhammad-irmatov/health_dataset/main/healt_info.csv")
df.head(3)
# Out:
#    Sno  AGE     SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME SURGERY_CODE  \
# 0    1   56  Female         BC            M6    NEPHROLOGY         M6.5
# 1    2   37    Male         BC            M6    NEPHROLOGY         M6.5
# 2    3   50    Male         BC            M6    NEPHROLOGY         M6.5
#
#                             SURGERY      VILLAGE MANDAL_NAME  ...  \
# 0  Maintenance Hemodialysis For Crf       Lolugu     Ponduru  ...
# 1  Maintenance Hemodialysis For Crf    Borivanka      Kaviti  ...
# 2  Maintenance Hemodialysis For Crf  Kapasakuddi      Kaviti  ...
#
#          CLAIM_DATE CLAIM_AMOUNT                                HOSP_NAME  \
# 0  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 1  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 2  22-03-2017 20:25        11500  Rims Govt. General Hospital, Srikakulam
#
#   HOSP_TYPE  HOSP_DISTRICT      SURGERY_DATE    DISCHARGE_DATE  \
# 0         G     Srikakulam  06-08-2013 00:00  07-09-2013 00:00
# 1         G     Srikakulam  08-08-2013 00:00  09-09-2013 00:00
# 2         G     Srikakulam  15-08-2013 00:00  18-10-2013 00:00
#
#   Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# 0              NO            NaN                D
# 1              NO            NaN                D
# 2              NO            NaN                D
#
# [3 rows x 23 columns]

# %%
df.info() # data haqida informatsiya oldik
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335394 entries, 0 to 335393
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sno               335394 non-null  int64
#  1   AGE               335394 non-null  int64
#  2   SEX               335394 non-null  object
#  3   CASTE_NAME        335394 non-null  object
#  4   CATEGORY_CODE     335394 non-null  object
#  5   CATEGORY_NAME     335394 non-null  object
#  6   SURGERY_CODE      335394 non-null  object
#  7   SURGERY           335394 non-null  object
#  8   VILLAGE           335394 non-null  object
#  9   MANDAL_NAME       335394 non-null  object
#  10  DISTRICT_NAME     335394 non-null  object
#  11  PREAUTH_DATE      335394 non-null  object
#  12  PREAUTH_AMT       335394 non-null  int64
#  13  CLAIM_DATE        335394 non-null  object
#  14  CLAIM_AMOUNT      335394 non-null  int64
#  15  HOSP_NAME         335394 non-null  object
#  16  HOSP_TYPE         335394 non-null  object
#  17  HOSP_DISTRICT     335394 non-null  object
#  18  SURGERY_DATE      335394 non-null  object
#  19  DISCHARGE_DATE    332717 non-null  object
#  20  Mortality Y / N   335394 non-null  object
#  21  MORTALITY_DATE    8238 non-null    object
#  22  SRC_REGISTRATION  335394 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 58.9+ MB

# %%
df.columns
# Out:
# Index(['Sno', 'AGE', 'SEX', 'CASTE_NAME', 'CATEGORY_CODE', 'CATEGORY_NAME',
#        'SURGERY_CODE', 'SURGERY', 'VILLAGE', 'MANDAL_NAME', 'DISTRICT_NAME',
#        'PREAUTH_DATE', 'PREAUTH_AMT', 'CLAIM_DATE', 'CLAIM_AMOUNT',
#        'HOSP_NAME', 'HOSP_TYPE', 'HOSP_DISTRICT', 'SURGERY_DATE',
#        'DISCHARGE_DATE', 'Mortality Y / N', 'MORTALITY_DATE',
#        'SRC_REGISTRATION'],
#       dtype='object')

# %%
df.columns = [
    't_r', 'yosh', 'jinsi', 'kasta_nomi', 'kategoriya_kodi', 'kategoriya_nomi',
    'operatsiya_kodi', 'operatsiya', 'qishloq', 'familiya', 'viloyat', 'oldindan_tasdiqlash_sanasi',
    'oldindan_tasdiqlash_summasi', 'davo_sanasi', 'davo_summasi', 'shifoxona_nomi', 'shifoxona_turi',
    'shifoxona_joylashgan_viloyat', 'Operatsiya_sana', 'uyga_chiqarilgan_sana', 'hayotmi', 'olim_sanasi',
    'royxatdan_otgan_manba'
    ]
df # dtaframe dagi ustunlar nomini tusnurali qilib o'zgartirib oldim
# Out:
#            t_r  yosh   jinsi kasta_nomi kategoriya_kodi  \
# 0            1    56  Female         BC              M6
# 1            2    37    Male         BC              M6
# 2            3    50    Male         BC              M6
# 3            4    45    Male         BC              M6
# 4            5    54    Male         BC              M6
# ...        ...   ...     ...        ...             ...
# 335389  335390    65    Male         SC              S3
# 335390  335391    54  Female         OC             S12
# 335391  335392    19  Female         SC             S12
# 335392  335393    50    Male         BC              S9
# 335393  335394    46  Female         SC             S12
#
#                  kategoriya_nomi operatsiya_kodi  \
# 0                     NEPHROLOGY            M6.5
# 1                     NEPHROLOGY            M6.5
# 2                     NEPHROLOGY            M6.5
# 3                     NEPHROLOGY            M6.5
# 4                     NEPHROLOGY            M6.5
# ...                          ...             ...
# 335389    OPHTHALMOLOGY  SURGERY            SU66
# 335390          MEDICAL ONCOLOGY         S12.1.4
# 335391          MEDICAL ONCOLOGY        S12.28.1
# 335392  GENITO URINARY SURGERIES          S9.3.4
# 335393          MEDICAL ONCOLOGY         S12.2.1
#
#                                                operatsiya  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         qishloq      familiya  ...       davo_sanasi  \
# 0                        Lolugu       Ponduru  ...  22-03-2017 20:25
# 1                     Borivanka        Kaviti  ...  22-03-2017 20:25
# 2                   Kapasakuddi        Kaviti  ...  22-03-2017 20:25
# 3                   Telikipenta   Sarubujjili  ...  22-03-2017 20:25
# 4                 Thandemvalasa    Srikakulam  ...  22-03-2017 20:25
# ...                         ...           ...  ...               ...
# 335389             Chintalapudi        Ponnur  ...  04-08-2017 21:23
# 335390  Udayagiri @ Kondayapale     Udayagiri  ...  02-08-2017 19:11
# 335391                  Vinduru         Gudur  ...  04-10-2017 19:46
# 335392                Duppituru  Atchutapuram  ...  04-08-2017 20:59
# 335393             Ananthavaram  Mummidivaram  ...  09-08-2017 19:43
#
#        davo_summasi                                     shifoxona_nomi  \
# 0             11000            Rims Govt. General Hospital, Srikakulam
# 1             11000            Rims Govt. General Hospital, Srikakulam
# 2             11500            Rims Govt. General Hospital, Srikakulam
# 3             11000            Rims Govt. General Hospital, Srikakulam
# 4             11000            Rims Govt. General Hospital, Srikakulam
# ...             ...                                                ...
# 335389        23320                                Sankar Eye Hospital
# 335390         7140  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...
# 335391         5000                                    M.N.J.Hospitals
# 335392        25000             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL
# 335393         2040  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...
#
#        shifoxona_turi  shifoxona_joylashgan_viloyat   Operatsiya_sana  \
# 0                   G                    Srikakulam  06-08-2013 00:00
# 1                   G                    Srikakulam  08-08-2013 00:00
# 2                   G                    Srikakulam  15-08-2013 00:00
# 3                   G                    Srikakulam  24-08-2013 00:00
# 4                   G                    Srikakulam  31-08-2013 00:00
# ...               ...                           ...               ...
# 335389              C                        Guntur  09-06-2017 00:00
# 335390              C                     Hyderabad  06-06-2017 00:00
# 335391              G                     Hyderabad  09-06-2017 00:00
# 335392              C                Vishakhapatnam  06-06-2017 00:00
# 335393              C                 East Godavari  07-06-2017 00:00
#
#        uyga_chiqarilgan_sana hayotmi olim_sanasi royxatdan_otgan_manba
# 0           07-09-2013 00:00      NO         NaN                     D
# 1           09-09-2013 00:00      NO         NaN                     D
# 2           18-10-2013 00:00      NO         NaN                     D
# 3           27-09-2013 00:00      NO         NaN                     D
# 4           02-10-2013 00:00      NO         NaN                     D
# ...                      ...     ...         ...                   ...
# 335389      10-06-2017 00:00      NO         NaN                     D
# 335390      06-06-2017 00:00      NO         NaN                     D
# 335391      10-06-2017 00:00      NO         NaN                     D
# 335392      10-06-2017 00:00      NO         NaN                     D
# 335393      07-06-2017 00:00      NO         NaN                    MC
#
# [335394 rows x 23 columns]

# %%
df.head()
# Out:
#      yosh   jinsi kasta_nomi kategoriya_kodi kategoriya_nomi operatsiya_kodi  \
# t_r
# 1      56  Female         BC              M6      NEPHROLOGY            M6.5
# 2      37    Male         BC              M6      NEPHROLOGY            M6.5
# 3      50    Male         BC              M6      NEPHROLOGY            M6.5
# 4      45    Male         BC              M6      NEPHROLOGY            M6.5
# 5      54    Male         BC              M6      NEPHROLOGY            M6.5
#
#                            operatsiya        qishloq     familiya     viloyat  \
# t_r
# 1    Maintenance Hemodialysis For Crf         Lolugu      Ponduru  Srikakulam
# 2    Maintenance Hemodialysis For Crf      Borivanka       Kaviti  Srikakulam
# 3    Maintenance Hemodialysis For Crf    Kapasakuddi       Kaviti  Srikakulam
# 4    Maintenance Hemodialysis For Crf    Telikipenta  Sarubujjili  Srikakulam
# 5    Maintenance Hemodialysis For Crf  Thandemvalasa   Srikakulam  Srikakulam
#
#      ...       davo_sanasi  davo_summasi  \
# t_r  ...
# 1    ...  22-03-2017 20:25         11000
# 2    ...  22-03-2017 20:25         11000
# 3    ...  22-03-2017 20:25         11500
# 4    ...  22-03-2017 20:25         11000
# 5    ...  22-03-2017 20:25         11000
#
#                               shifoxona_nomi  shifoxona_turi  \
# t_r
# 1    Rims Govt. General Hospital, Srikakulam               G
# 2    Rims Govt. General Hospital, Srikakulam               G
# 3    Rims Govt. General Hospital, Srikakulam               G
# 4    Rims Govt. General Hospital, Srikakulam               G
# 5    Rims Govt. General Hospital, Srikakulam               G
#
#     shifoxona_joylashgan_viloyat   Operatsiya_sana uyga_chiqarilgan_sana  \
# t_r
# 1                     Srikakulam  06-08-2013 00:00      07-09-2013 00:00
# 2                     Srikakulam  08-08-2013 00:00      09-09-2013 00:00
# 3                     Srikakulam  15-08-2013 00:00      18-10-2013 00:00
# 4                     Srikakulam  24-08-2013 00:00      27-09-2013 00:00
# 5                     Srikakulam  31-08-2013 00:00      02-10-2013 00:00
#
#     hayotmi olim_sanasi royxatdan_otgan_manba
# t_r
# 1        NO         NaN                     D
# 2        NO         NaN                     D
# 3        NO         NaN                     D
# 4        NO         NaN                     D
# 5        NO         NaN                     D
#
# [5 rows x 22 columns]

# %% [markdown]
# Bu dataset sug'urta kompaniyasining real ma'lumotlardan tuzilgan. Bu datasetda 480000 qator sug'urta ma'lumotlar tashkil topgan.
# Quyida datasetning ba'zi ustunlari haqida qisqacha ma'lumot
#
# *   Sno = seriya raqami
# *   AGE = yoshi
# *   SEX = jinsi (female = ayol, male = erkak)
# *   CASTE_NAME = kasta nomi (Hindistonda har bir inson ma'lum bir kastaga oid bo'ladi)
# *   CATEGORY_CODE = kategoriya kodi
# *   CATEGORY_Name = kategoriya nomi
# *   SURGERY_CODE = operatsiya kodi
# *   Mandal_Name = mandal nomlanishi ya'ni familiyasi desak ham bo'ladi
# *   Mortality Y/N = vafot etgan yoki vafot etmaganligi
# *   MORTALITY_DATE = qachon vafot etganligi

# %% [markdown]
# ### **1-mashq**. Datasetdagi barcha takrorlangan qatorlar sonini toping

# %%
# Javobni shuyerga yozing
df_duplicated = df[df.duplicated()] #duplikat ma'lumotlarni chiqarib oldim
df_duplicated # bu duplikat qilingan ma'lumotlar 30 qator 22 ustundan iborat
# Out:
#         yosh          jinsi  kasta_nomi kategoriya_kodi  \
# t_r
# 25067      0  Female(Child)  Minorities              M4
# 42636      0    Male(Child)          ST              M4
# 57793     33           Male          BC              S3
# 58764     44           Male          BC              S3
# 77985      9  Female(Child)          BC              S2
# 103125    72           Male          BC              S3
# 123861    61         Female          BC              S3
# 157561    43         Female          BC              S3
# 158757    40           Male          OC              S3
# 168315    51           Male          OC              S3
# 184776    47         Female          BC              S3
# 197247    49         Female          BC              S3
# 214716    48           Male          BC              S3
# 220375    35           Male          BC              S3
# 227266    65           Male          OC              S3
# 231190    57           Male          BC              S3
# 236019    64           Male          BC              S3
# 253139    48           Male          OC             S15
# 256228    43           Male          BC              S3
# 260371    43           Male          BC              S3
# 265591    43         Female  Minorities              S3
# 281968    41         Female          BC              S3
# 286382    48         Female          BC              S3
# 288894    41           Male          OC              S3
# 298564    42           Male          BC              S3
# 304855    54         Female          SC              S3
# 313895    55           Male          OC              S3
# 314601    30         Female          BC             S15
# 314602    30         Female          BC             S15
# 314603    30         Female          BC             S15
#
#                kategoriya_nomi operatsiya_kodi  \
# t_r
# 25067               PEDIATRICS         M4.1.15
# 42636               PEDIATRICS          M4.1.5
# 57793   OPHTHALMOLOGY  SURGERY          S3.2.7
# 58764   OPHTHALMOLOGY  SURGERY          S3.3.5
# 77985             ENT  SURGERY          S2.1.5
# 103125  OPHTHALMOLOGY  SURGERY          S3.3.5
# 123861  OPHTHALMOLOGY  SURGERY          S3.3.5
# 157561  OPHTHALMOLOGY  SURGERY          S3.3.5
# 158757  OPHTHALMOLOGY  SURGERY          S3.3.5
# 168315  OPHTHALMOLOGY  SURGERY          S3.3.5
# 184776  OPHTHALMOLOGY  SURGERY          S3.3.5
# 197247  OPHTHALMOLOGY  SURGERY          S3.3.5
# 214716  OPHTHALMOLOGY  SURGERY          S3.3.5
# 220375  OPHTHALMOLOGY  SURGERY          S3.3.5
# 227266  OPHTHALMOLOGY  SURGERY          S3.3.5
# 231190  OPHTHALMOLOGY  SURGERY          S3.3.5
# 236019  OPHTHALMOLOGY  SURGERY          S3.3.5
# 253139             POLY TRAUMA         S15.8.1
# 256228  OPHTHALMOLOGY  SURGERY          S3.3.5
# 260371  OPHTHALMOLOGY  SURGERY          S3.3.5
# 265591  OPHTHALMOLOGY  SURGERY          S3.3.5
# 281968  OPHTHALMOLOGY  SURGERY          S3.2.7
# 286382  OPHTHALMOLOGY  SURGERY          S3.3.5
# 288894  OPHTHALMOLOGY  SURGERY          S3.3.5
# 298564  OPHTHALMOLOGY  SURGERY          S3.3.5
# 304855  OPHTHALMOLOGY  SURGERY          S3.3.5
# 313895  OPHTHALMOLOGY  SURGERY          S3.3.5
# 314601             POLY TRAUMA         S15.6.3
# 314602             POLY TRAUMA         S15.6.2
# 314603             POLY TRAUMA         S15.7.2
#
#                                                operatsiya           qishloq  \
# t_r
# 25067   Medical Management of Term Baby Severe Hyperbi...        Machavaram
# 42636   Medicalmanagement of Preterm baby of 33 To 34 ...      Undrajavaram
# 57793   Amniotic Membrane Graft for Cornea/Sclera (12....           Yeditha
# 58764                    Photocoagulation for Retinopathy         22nd Ward
# 77985                Myringotomy with grommet for one ear       Epuru Palem
# 103125                   Photocoagulation for Retinopathy        B. Savaram
# 123861                   Photocoagulation for Retinopathy          Koruturu
# 157561                   Photocoagulation for Retinopathy             Ojili
# 158757                   Photocoagulation for Retinopathy         11th Ward
# 168315                   Photocoagulation for Retinopathy  Butchireddypalem
# 184776                   Photocoagulation for Retinopathy       Malakapalle
# 197247                   Photocoagulation for Retinopathy    Srirangapatnam
# 214716                   Photocoagulation for Retinopathy         Kunavaram
# 220375                   Photocoagulation for Retinopathy           Potluru
# 227266                   Photocoagulation for Retinopathy           Ward-16
# 231190                   Photocoagulation for Retinopathy          Kotapadu
# 236019                   Photocoagulation for Retinopathy       Ward No. 23
# 253139  Surgical Management with Facial Bone Fractures...             Darsi
# 256228                   Photocoagulation for Retinopathy        Kodurupadu
# 260371                   Photocoagulation for Retinopathy        Kodurupadu
# 265591                   Photocoagulation for Retinopathy           Ward 24
# 281968  Amniotic Membrane Graft for Cornea/Sclera (12....         Galavilli
# 286382                   Photocoagulation for Retinopathy         26th Ward
# 288894                   Photocoagulation for Retinopathy         Nandamuru
# 298564                   Photocoagulation for Retinopathy     TATAIAH NAGAR
# 304855                   Photocoagulation for Retinopathy  Purushothapatnam
# 313895                   Photocoagulation for Retinopathy         15th Ward
# 314601  Surgical Management of wound In Compound Fract...     Thummalapenta
# 314602  Surgical Management of Grade III Compound Frac...     Thummalapenta
# 314603  Surgical management with K-Wiring for Small bo...     Thummalapenta
#
#                     familiya        viloyat  ...       davo_sanasi  \
# t_r                                          ...
# 25067             Machavaram         Guntur  ...  10-01-2017 00:16
# 42636           Undrajavaram  West Godavari  ...  20-03-2017 22:43
# 57793              Mandapeta  East Godavari  ...  12-01-2017 00:43
# 58764   Bhimavaram Municipal  West Godavari  ...  12-01-2017 00:39
# 77985                Chirala       Prakasam  ...  11-01-2017 22:30
# 103125                Razole  East Godavari  ...  11-01-2017 21:50
# 123861            Indukurpet        Nellore  ...  20-01-2017 19:20
# 157561                 Ojili        Nellore  ...  17-02-2017 19:18
# 158757        Rajahmundry(M)  East Godavari  ...  01-03-2017 21:18
# 168315      Butchireddipalem        Nellore  ...  08-03-2017 19:27
# 184776             Tallapudi  West Godavari  ...  17-03-2017 20:03
# 197247             Korukonda  East Godavari  ...  22-03-2017 21:13
# 214716          Uppalaguptam  East Godavari  ...  06-04-2017 21:36
# 220375               Gudluru       Prakasam  ...  06-04-2017 21:08
# 227266             Proddutur     YSR Kadapa  ...  17-04-2017 20:09
# 231190             Ponnaluru       Prakasam  ...  19-04-2017 20:44
# 236019           Venkatagiri        Nellore  ...  24-04-2017 20:50
# 253139                 Darsi       Prakasam  ...  15-05-2017 22:22
# 256228             Bhimadole  West Godavari  ...  10-05-2017 19:27
# 260371             Bhimadole  West Godavari  ...  10-05-2017 19:07
# 265591         Rayachoti (M)     YSR Kadapa  ...  15-05-2017 20:39
# 281968            Balajipeta   Vizianagaram  ...  30-05-2017 21:09
# 286382        Rajahmundry(M)  East Godavari  ...  16-05-2017 20:09
# 288894               Kovvuru  West Godavari  ...  17-05-2017 20:11
# 298564       TIRUPATHI URBAN       Chittoor  ...  29-05-2017 21:44
# 304855         Seethanagaram  East Godavari  ...  06-06-2017 20:47
# 313895        Rajahmundry(M)  East Godavari  ...  04-07-2017 21:18
# 314601                Kavali        Nellore  ...  19-08-2017 20:07
# 314602                Kavali        Nellore  ...  19-08-2017 20:07
# 314603                Kavali        Nellore  ...  19-08-2017 20:07
#
#         davo_summasi                            shifoxona_nomi  \
# t_r
# 25067          35000       Government General Hospital, Guntur
# 42636          35000  APPLE HOSPITAL A UNIT OF TANUKU HOSPITAL
# 57793          11000                        AKIRA EYE HOSPITAL
# 58764           2000                        AKIRA EYE HOSPITAL
# 77985          10200                      Nalluri Nursing Home
# 103125          2040                   Pushpagiri Eye Hospital
# 123861          2000   Modern Eye Hospital and Research Centre
# 157561          2000   Modern Eye Hospital and Research Centre
# 158757          2000                        AKIRA EYE HOSPITAL
# 168315          2000   Modern Eye Hospital and Research Centre
# 184776          2000                        AKIRA EYE HOSPITAL
# 197247          2000                     Goutami Eye Institute
# 214716          2000                     Goutami Eye Institute
# 220375          2000   Modern Eye Hospital and Research Centre
# 227266          2000   Modern Eye Hospital and Research Centre
# 231190          2000   Modern Eye Hospital and Research Centre
# 236019          2000   Modern Eye Hospital and Research Centre
# 253139         15300                      Nalluri Nursing Home
# 256228          2040                   Pushpagiri Eye Hospital
# 260371          2040                   Pushpagiri Eye Hospital
# 265591          2000        SURENDRA MULTISPECAILITY HOSPITALS
# 281968         11000      Shankar Foundation And Eye Institute
# 286382          2000                        AKIRA EYE HOSPITAL
# 288894          2000                     Goutami Eye Institute
# 298564          2000        SURENDRA MULTISPECAILITY HOSPITALS
# 304855          2000                        AKIRA EYE HOSPITAL
# 313895          2040                   Pushpagiri Eye Hospital
# 314601         15000                        Kandukuri Hospital
# 314602         15000                        Kandukuri Hospital
# 314603         15000                        Kandukuri Hospital
#
#         shifoxona_turi shifoxona_joylashgan_viloyat   Operatsiya_sana  \
# t_r
# 25067                G                       Guntur  27-07-2016 00:00
# 42636                C                West Godavari  03-09-2016 00:00
# 57793                C                East Godavari  28-09-2016 00:00
# 58764                C                East Godavari  29-09-2016 00:00
# 77985                C                     Prakasam  23-10-2016 00:00
# 103125               C                    Hyderabad  17-11-2016 00:00
# 123861               C                      Nellore  06-12-2016 00:00
# 157561               C                      Nellore  05-01-2017 00:00
# 158757               C                East Godavari  09-01-2017 00:00
# 168315               C                      Nellore  18-01-2017 00:00
# 184776               C                East Godavari  31-01-2017 00:00
# 197247               C                East Godavari  11-02-2017 00:00
# 214716               C                East Godavari  25-02-2017 00:00
# 220375               C                      Nellore  02-03-2017 00:00
# 227266               C                      Nellore  08-03-2017 00:00
# 231190               C                      Nellore  11-03-2017 00:00
# 236019               C                      Nellore  15-03-2017 00:00
# 253139               C                     Prakasam  01-04-2017 00:00
# 256228               C                    Hyderabad  01-04-2017 00:00
# 260371               C                    Hyderabad  06-04-2017 00:00
# 265591               C                     Chittoor  15-04-2017 00:00
# 281968               C               Vishakhapatnam  22-04-2017 00:00
# 286382               C                East Godavari  27-04-2017 00:00
# 288894               C                East Godavari  29-04-2017 00:00
# 298564               C                     Chittoor  11-05-2017 00:00
# 304855               C                East Godavari  11-05-2017 00:00
# 313895               C                    Hyderabad  19-05-2017 00:00
# 314601               C                      Nellore  15-05-2017 00:00
# 314602               C                      Nellore  15-05-2017 00:00
# 314603               C                      Nellore  15-05-2017 00:00
#
#        uyga_chiqarilgan_sana hayotmi olim_sanasi royxatdan_otgan_manba
# t_r
# 25067       30-07-2016 00:00      NO         NaN                     D
# 42636       14-09-2016 00:00      NO         NaN                     D
# 57793       30-09-2016 00:00      NO         NaN                     D
# 58764       30-09-2016 00:00      NO         NaN                     D
# 77985       24-10-2016 00:00      NO         NaN                     D
# 103125      19-11-2016 00:00      NO         NaN                     D
# 123861      06-12-2016 00:00      NO         NaN                     D
# 157561      05-01-2017 00:00      NO         NaN                     D
# 158757      09-01-2017 00:00      NO         NaN                     D
# 168315      18-01-2017 00:00      NO         NaN                     D
# 184776      01-02-2017 00:00      NO         NaN                     D
# 197247      11-02-2017 00:00      NO         NaN                     D
# 214716      25-02-2017 00:00      NO         NaN                     D
# 220375      02-03-2017 00:00      NO         NaN                     D
# 227266      08-03-2017 00:00      NO         NaN                     D
# 231190      11-03-2017 00:00      NO         NaN                     D
# 236019      15-03-2017 00:00      NO         NaN                     D
# 253139      05-04-2017 00:00      NO         NaN                     D
# 256228      06-04-2017 00:00      NO         NaN                     D
# 260371      06-04-2017 00:00      NO         NaN                     D
# 265591      16-04-2017 00:00      NO         NaN                     D
# 281968      24-04-2017 00:00      NO         NaN                     D
# 286382      27-04-2017 00:00      NO         NaN                     D
# 288894      29-04-2017 00:00      NO         NaN                     D
# 298564      12-05-2017 00:00      NO         NaN                     D
# 304855      12-05-2017 00:00      NO         NaN                     D
# 313895      20-05-2017 00:00      NO         NaN                     D
# 314601      22-05-2017 00:00      NO         NaN                     D
# 314602      22-05-2017 00:00      NO         NaN                     D
# 314603      22-05-2017 00:00      NO         NaN                     D
#
# [30 rows x 22 columns]

# %%
df.columns #['T/r', 'Kategoriya kodi', 'Operatsiya kodi', 'Tuman (yoki mahalla) nomi', 'Tuman nomi', 'Shifoxona joylashgan tuman']
# Out:
# Index(['yosh', 'jinsi', 'kasta_nomi', 'kategoriya_kodi', 'kategoriya_nomi',
#        'operatsiya_kodi', 'operatsiya', 'qishloq', 'familiya', 'viloyat',
#        'oldindan_tasdiqlash_sanasi', 'oldindan_tasdiqlash_summasi',
#        'davo_sanasi', 'davo_summasi', 'shifoxona_nomi', 'shifoxona_turi',
#        'shifoxona_joylashgan_viloyat', 'Operatsiya_sana',
#        'uyga_chiqarilgan_sana', 'hayotmi', 'olim_sanasi',
#        'royxatdan_otgan_manba'],
#       dtype='object')

# %%
df = df.reset_index()
df
# Out:
#          index     t_r  yosh   jinsi kasta_nomi kategoriya_kodi  \
# 0            0       1    56  Female         BC              M6
# 1            1       2    37    Male         BC              M6
# 2            2       3    50    Male         BC              M6
# 3            3       4    45    Male         BC              M6
# 4            4       5    54    Male         BC              M6
# ...        ...     ...   ...     ...        ...             ...
# 335389  335389  335390    65    Male         SC              S3
# 335390  335390  335391    54  Female         OC             S12
# 335391  335391  335392    19  Female         SC             S12
# 335392  335392  335393    50    Male         BC              S9
# 335393  335393  335394    46  Female         SC             S12
#
#                  kategoriya_nomi operatsiya_kodi  \
# 0                     NEPHROLOGY            M6.5
# 1                     NEPHROLOGY            M6.5
# 2                     NEPHROLOGY            M6.5
# 3                     NEPHROLOGY            M6.5
# 4                     NEPHROLOGY            M6.5
# ...                          ...             ...
# 335389    OPHTHALMOLOGY  SURGERY            SU66
# 335390          MEDICAL ONCOLOGY         S12.1.4
# 335391          MEDICAL ONCOLOGY        S12.28.1
# 335392  GENITO URINARY SURGERIES          S9.3.4
# 335393          MEDICAL ONCOLOGY         S12.2.1
#
#                                                operatsiya  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         qishloq  ...       davo_sanasi davo_summasi  \
# 0                        Lolugu  ...  22-03-2017 20:25        11000
# 1                     Borivanka  ...  22-03-2017 20:25        11000
# 2                   Kapasakuddi  ...  22-03-2017 20:25        11500
# 3                   Telikipenta  ...  22-03-2017 20:25        11000
# 4                 Thandemvalasa  ...  22-03-2017 20:25        11000
# ...                         ...  ...               ...          ...
# 335389             Chintalapudi  ...  04-08-2017 21:23        23320
# 335390  Udayagiri @ Kondayapale  ...  02-08-2017 19:11         7140
# 335391                  Vinduru  ...  04-10-2017 19:46         5000
# 335392                Duppituru  ...  04-08-2017 20:59        25000
# 335393             Ananthavaram  ...  09-08-2017 19:43         2040
#
#                                            shifoxona_nomi  shifoxona_turi  \
# 0                 Rims Govt. General Hospital, Srikakulam               G
# 1                 Rims Govt. General Hospital, Srikakulam               G
# 2                 Rims Govt. General Hospital, Srikakulam               G
# 3                 Rims Govt. General Hospital, Srikakulam               G
# 4                 Rims Govt. General Hospital, Srikakulam               G
# ...                                                   ...             ...
# 335389                                Sankar Eye Hospital               C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...               C
# 335391                                    M.N.J.Hospitals               G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL               C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...               C
#
#        shifoxona_joylashgan_viloyat   Operatsiya_sana uyga_chiqarilgan_sana  \
# 0                        Srikakulam  06-08-2013 00:00      07-09-2013 00:00
# 1                        Srikakulam  08-08-2013 00:00      09-09-2013 00:00
# 2                        Srikakulam  15-08-2013 00:00      18-10-2013 00:00
# 3                        Srikakulam  24-08-2013 00:00      27-09-2013 00:00
# 4                        Srikakulam  31-08-2013 00:00      02-10-2013 00:00
# ...                             ...               ...                   ...
# 335389                       Guntur  09-06-2017 00:00      10-06-2017 00:00
# 335390                    Hyderabad  06-06-2017 00:00      06-06-2017 00:00
# 335391                    Hyderabad  09-06-2017 00:00      10-06-2017 00:00
# 335392               Vishakhapatnam  06-06-2017 00:00      10-06-2017 00:00
# 335393                East Godavari  07-06-2017 00:00      07-06-2017 00:00
#
#        hayotmi olim_sanasi royxatdan_otgan_manba
# 0           NO         NaN                     D
# 1           NO         NaN                     D
# 2           NO         NaN                     D
# 3           NO         NaN                     D
# 4           NO         NaN                     D
# ...        ...         ...                   ...
# 335389      NO         NaN                     D
# 335390      NO         NaN                     D
# 335391      NO         NaN                     D
# 335392      NO         NaN                     D
# 335393      NO         NaN                    MC
#
# [335394 rows x 24 columns]

# %% [markdown]
# #### **2-mashq**. Datasetdagi quyidagi ustunlar o'chirib yuborilsin:<br>
# *   Sno
# *   CATEGORY_CODE
# *   SURGERY_CODE
# *   MANDAL_NAME
# *   DISTRICT_NAME
# *   HOSP_DISTRICT
# <BR>

# %%
# Javobni shuyerga yozing
df1 = df.drop(['t_r','kategoriya_kodi','operatsiya_kodi','qishloq','familiya','viloyat','shifoxona_joylashgan_viloyat'], axis=1)
df1
# Out:
#          index  yosh   jinsi kasta_nomi           kategoriya_nomi  \
# 0            0    56  Female         BC                NEPHROLOGY
# 1            1    37    Male         BC                NEPHROLOGY
# 2            2    50    Male         BC                NEPHROLOGY
# 3            3    45    Male         BC                NEPHROLOGY
# 4            4    54    Male         BC                NEPHROLOGY
# ...        ...   ...     ...        ...                       ...
# 335389  335389    65    Male         SC    OPHTHALMOLOGY  SURGERY
# 335390  335390    54  Female         OC          MEDICAL ONCOLOGY
# 335391  335391    19  Female         SC          MEDICAL ONCOLOGY
# 335392  335392    50    Male         BC  GENITO URINARY SURGERIES
# 335393  335393    46  Female         SC          MEDICAL ONCOLOGY
#
#                                                operatsiya  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#        oldindan_tasdiqlash_sanasi  oldindan_tasdiqlash_summasi  \
# 0                03-08-2013 20:38                        12500
# 1                06-08-2013 07:26                        12500
# 2                09-08-2013 18:30                        12500
# 3                24-08-2013 19:37                        12500
# 4                28-08-2013 17:03                        12500
# ...                           ...                          ...
# 335389           08-06-2017 06:40                        23320
# 335390           05-06-2017 22:35                         7140
# 335391           06-06-2017 06:13                         5000
# 335392           05-06-2017 23:37                        25000
# 335393           06-06-2017 23:02                         2040
#
#              davo_sanasi  davo_summasi  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                            shifoxona_nomi shifoxona_turi  \
# 0                 Rims Govt. General Hospital, Srikakulam              G
# 1                 Rims Govt. General Hospital, Srikakulam              G
# 2                 Rims Govt. General Hospital, Srikakulam              G
# 3                 Rims Govt. General Hospital, Srikakulam              G
# 4                 Rims Govt. General Hospital, Srikakulam              G
# ...                                                   ...            ...
# 335389                                Sankar Eye Hospital              C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...              C
# 335391                                    M.N.J.Hospitals              G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL              C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...              C
#
#          Operatsiya_sana uyga_chiqarilgan_sana hayotmi olim_sanasi  \
# 0       06-08-2013 00:00      07-09-2013 00:00      NO         NaN
# 1       08-08-2013 00:00      09-09-2013 00:00      NO         NaN
# 2       15-08-2013 00:00      18-10-2013 00:00      NO         NaN
# 3       24-08-2013 00:00      27-09-2013 00:00      NO         NaN
# 4       31-08-2013 00:00      02-10-2013 00:00      NO         NaN
# ...                  ...                   ...     ...         ...
# 335389  09-06-2017 00:00      10-06-2017 00:00      NO         NaN
# 335390  06-06-2017 00:00      06-06-2017 00:00      NO         NaN
# 335391  09-06-2017 00:00      10-06-2017 00:00      NO         NaN
# 335392  06-06-2017 00:00      10-06-2017 00:00      NO         NaN
# 335393  07-06-2017 00:00      07-06-2017 00:00      NO         NaN
#
#        royxatdan_otgan_manba
# 0                          D
# 1                          D
# 2                          D
# 3                          D
# 4                          D
# ...                      ...
# 335389                     D
# 335390                     D
# 335391                     D
# 335392                     D
# 335393                    MC
#
# [335394 rows x 17 columns]

# %% [markdown]
# #### **3-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni unique funksiyasi orqali tekshiring.

# %%
# Javobni shuyerga yozing
df['jinsi'].unique()
# Out:
# array([nan])

# %% [markdown]
# #### **4-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni **Erkak** va **Ayol** ga o'zgartiring:
# O'zgartirish quyidagicha bo'lsin:
#
#
# *   Male -> Erkak
# *   Male(child) -> Erkak
# *   Female - > Ayol
# *   Female(child) - Ayol
# *   MALE -> Erkak
# *   FEMALE -> Ayol

# %%
# Javobni shuyerga yozing
dict = {"Male":"erkak", "Male(child)":"erkak","Female":"ayol","Female(child)":"ayol","MALE":"erkak","FEMALE":"ayol"}
df['jinsi'] = df['jinsi'].map(dict).fillna(df['jinsi'])
df
# Out:
# <ipython-input-53-257065fefa95>:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['jinsi'] = df['jinsi'].map(dict).fillna(df['jinsi'])
#          index     t_r  yosh  jinsi kasta_nomi kategoriya_kodi  \
# 0            0       1    56    NaN         BC              M6
# 1            1       2    37    NaN         BC              M6
# 2            2       3    50    NaN         BC              M6
# 3            3       4    45    NaN         BC              M6
# 4            4       5    54    NaN         BC              M6
# ...        ...     ...   ...    ...        ...             ...
# 335389  335389  335390    65    NaN         SC              S3
# 335390  335390  335391    54    NaN         OC             S12
# 335391  335391  335392    19    NaN         SC             S12
# 335392  335392  335393    50    NaN         BC              S9
# 335393  335393  335394    46    NaN         SC             S12
#
#                  kategoriya_nomi operatsiya_kodi  \
# 0                     NEPHROLOGY            M6.5
# 1                     NEPHROLOGY            M6.5
# 2                     NEPHROLOGY            M6.5
# 3                     NEPHROLOGY            M6.5
# 4                     NEPHROLOGY            M6.5
# ...                          ...             ...
# 335389    OPHTHALMOLOGY  SURGERY            SU66
# 335390          MEDICAL ONCOLOGY         S12.1.4
# 335391          MEDICAL ONCOLOGY        S12.28.1
# 335392  GENITO URINARY SURGERIES          S9.3.4
# 335393          MEDICAL ONCOLOGY         S12.2.1
#
#                                                operatsiya  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         qishloq  ...       davo_sanasi davo_summasi  \
# 0                        Lolugu  ...  22-03-2017 20:25        11000
# 1                     Borivanka  ...  22-03-2017 20:25        11000
# 2                   Kapasakuddi  ...  22-03-2017 20:25        11500
# 3                   Telikipenta  ...  22-03-2017 20:25        11000
# 4                 Thandemvalasa  ...  22-03-2017 20:25        11000
# ...                         ...  ...               ...          ...
# 335389             Chintalapudi  ...  04-08-2017 21:23        23320
# 335390  Udayagiri @ Kondayapale  ...  02-08-2017 19:11         7140
# 335391                  Vinduru  ...  04-10-2017 19:46         5000
# 335392                Duppituru  ...  04-08-2017 20:59        25000
# 335393             Ananthavaram  ...  09-08-2017 19:43         2040
#
#                                            shifoxona_nomi  shifoxona_turi  \
# 0                 Rims Govt. General Hospital, Srikakulam               G
# 1                 Rims Govt. General Hospital, Srikakulam               G
# 2                 Rims Govt. General Hospital, Srikakulam               G
# 3                 Rims Govt. General Hospital, Srikakulam               G
# 4                 Rims Govt. General Hospital, Srikakulam               G
# ...                                                   ...             ...
# 335389                                Sankar Eye Hospital               C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...               C
# 335391                                    M.N.J.Hospitals               G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL               C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...               C
#
#        shifoxona_joylashgan_viloyat   Operatsiya_sana uyga_chiqarilgan_sana  \
# 0                        Srikakulam  06-08-2013 00:00      07-09-2013 00:00
# 1                        Srikakulam  08-08-2013 00:00      09-09-2013 00:00
# 2                        Srikakulam  15-08-2013 00:00      18-10-2013 00:00
# 3                        Srikakulam  24-08-2013 00:00      27-09-2013 00:00
# 4                        Srikakulam  31-08-2013 00:00      02-10-2013 00:00
# ...                             ...               ...                   ...
# 335389                       Guntur  09-06-2017 00:00      10-06-2017 00:00
# 335390                    Hyderabad  06-06-2017 00:00      06-06-2017 00:00
# 335391                    Hyderabad  09-06-2017 00:00      10-06-2017 00:00
# 335392               Vishakhapatnam  06-06-2017 00:00      10-06-2017 00:00
# 335393                East Godavari  07-06-2017 00:00      07-06-2017 00:00
#
#        hayotmi olim_sanasi royxatdan_otgan_manba
# 0           NO         NaN                     D
# 1           NO         NaN                     D
# 2           NO         NaN                     D
# 3           NO         NaN                     D
# 4           NO         NaN                     D
# ...        ...         ...                   ...
# 335389      NO         NaN                     D
# 335390      NO         NaN                     D
# 335391      NO         NaN                     D
# 335392      NO         NaN                     D
# 335393      NO         NaN                    MC
#
# [335394 rows x 24 columns]

# %% [markdown]
# #### **5-mashq**. Endi xuddi shu SEX columndagi ma'lumotlarni raqamlarga o'zgartiring: Erkaklarni 1 raqamiga, Ayollarni 0 raqamiga o'zgartiring.
# *   Erkak -> 1
# *   Ayol -> 0

# %%
# Javobni shuyerga yozing

# %% [markdown]
# #### **6-mashq**. Shu jarayonni HOSP_TYPE ustuni uchun ham amalga oshiring.
# *   G - General hospital (umumiy kasalxona) degani
# *   C - Special hospital (maxsus kasalxona) degani
# <br><b>O'zgarish quyidagicha bo'lsin:</b>
# *   G -> Umumiy
# *   C -> Maxsus

# %%
# Javobni shuyerga yozing
df.columns
df[['shifoxona_turi']] # shifonalarni chiqarib oldik
df['shifoxona_turi'].unique()
dict = {"G":"umumiy","S":"maxsus"}
df['shifoxona_turi'].map(dict)
# Out:
# 0         umumiy
# 1         umumiy
# 2         umumiy
# 3         umumiy
# 4         umumiy
#            ...
# 335389       NaN
# 335390       NaN
# 335391    umumiy
# 335392       NaN
# 335393       NaN
# Name: shifoxona_turi, Length: 335394, dtype: object

# %% [markdown]
# #### **7-mashq**. O'zgartirish amalga oshirilgach, HOSP_TYPE ustunida qancha Umumiy va qancha Maxsus kasalxonalar borligini ham aniqlang

# %%
# Javobni shuyerga yozing
df['shifoxona_turi'].value_counts()
# Out:
# shifoxona_turi
# C    241139
# G     94255
# Name: count, dtype: int64

# %% [markdown]
# #### **8-mashq**. Datasetda qancha takrorlangan qatorlar borligini aniqlang

# %%
# Javobni shuyerga yozing
df.duplicated().value_counts()
#sum(df.duplicated())
# Out:
# False    335394
# Name: count, dtype: int64

# %% [markdown]
# #### **9-mashq**. Datasetda barcha takrorlangan qatorlarni o'chirib yuboring

# %%
# Javobni shuyerga yozing
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 335389    False
# 335390    False
# 335391    False
# 335392    False
# 335393    False
# Length: 335394, dtype: bool

# %%
df.columns
# Out:
# Index(['index', 't_r', 'yosh', 'jinsi', 'kasta_nomi', 'kategoriya_kodi',
#        'kategoriya_nomi', 'operatsiya_kodi', 'operatsiya', 'qishloq',
#        'familiya', 'viloyat', 'oldindan_tasdiqlash_sanasi',
#        'oldindan_tasdiqlash_summasi', 'davo_sanasi', 'davo_summasi',
#        'shifoxona_nomi', 'shifoxona_turi', 'shifoxona_joylashgan_viloyat',
#        'Operatsiya_sana', 'uyga_chiqarilgan_sana', 'hayotmi', 'olim_sanasi',
#        'royxatdan_otgan_manba'],
#       dtype='object')

# %% [markdown]
# #### **10-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning o'rtacha qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby("shifoxona_turi")["davo_summasi"].mean()
# Out:
# shifoxona_turi
# C    30272.214457
# G    22683.900769
# Name: davo_summasi, dtype: float64

# %% [markdown]
# #### **11-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning minimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby("shifoxona_turi")["davo_summasi"].min()
# Out:
# shifoxona_turi
# C    2
# G    2
# Name: davo_summasi, dtype: int64

# %% [markdown]
# #### **12-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), CLAIM_AMOUNTning maksimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby("shifoxona_turi")["davo_summasi"].max()
# Out:
# shifoxona_turi
# C    520000
# G    520000
# Name: davo_summasi, dtype: int64

# %% [markdown]
# .agg() yordamida istalgan funksiyalarni chaqirishimiz mumkin, misol uchun numpy dagi mean (o'rta qiymat) funiksiyasini ham qo'shamiz. Natijalarni faqat price ustuni uchun chiqaramiz:

# %%
df.head()
# Out:
#    index  t_r  yosh  jinsi kasta_nomi kategoriya_kodi kategoriya_nomi  \
# 0      0    1    56    NaN         BC              M6      NEPHROLOGY
# 1      1    2    37    NaN         BC              M6      NEPHROLOGY
# 2      2    3    50    NaN         BC              M6      NEPHROLOGY
# 3      3    4    45    NaN         BC              M6      NEPHROLOGY
# 4      4    5    54    NaN         BC              M6      NEPHROLOGY
#
#   operatsiya_kodi                        operatsiya        qishloq  ...  \
# 0            M6.5  Maintenance Hemodialysis For Crf         Lolugu  ...
# 1            M6.5  Maintenance Hemodialysis For Crf      Borivanka  ...
# 2            M6.5  Maintenance Hemodialysis For Crf    Kapasakuddi  ...
# 3            M6.5  Maintenance Hemodialysis For Crf    Telikipenta  ...
# 4            M6.5  Maintenance Hemodialysis For Crf  Thandemvalasa  ...
#
#         davo_sanasi davo_summasi                           shifoxona_nomi  \
# 0  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 1  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 2  22-03-2017 20:25        11500  Rims Govt. General Hospital, Srikakulam
# 3  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 4  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
#
#    shifoxona_turi shifoxona_joylashgan_viloyat   Operatsiya_sana  \
# 0               G                   Srikakulam  06-08-2013 00:00
# 1               G                   Srikakulam  08-08-2013 00:00
# 2               G                   Srikakulam  15-08-2013 00:00
# 3               G                   Srikakulam  24-08-2013 00:00
# 4               G                   Srikakulam  31-08-2013 00:00
#
#   uyga_chiqarilgan_sana hayotmi olim_sanasi royxatdan_otgan_manba
# 0      07-09-2013 00:00      NO         NaN                     D
# 1      09-09-2013 00:00      NO         NaN                     D
# 2      18-10-2013 00:00      NO         NaN                     D
# 3      27-09-2013 00:00      NO         NaN                     D
# 4      02-10-2013 00:00      NO         NaN                     D
#
# [5 rows x 24 columns]

# %% [markdown]
# #### **13-mashq**. Datasetdan jinsiga ko'ra CLAIM_AMOUNTning min, max va o'rta qiymatlarni agg() usuli yordamida toping.

# %%
# Javobni shuyerga yozing
df.groupby("yosh")["davo_summasi"].agg(["min", "max", "mean"])
# Out:
#         min     max          mean
# yosh
# 0      1000  520000  31658.075340
# 1      1000  520000  38424.015045
# 2      2000  520000  28130.172721
# 3         2  520000  28073.329173
# 4         2  520000  28222.820637
# ...     ...     ...           ...
# 95    10000   30000  24775.000000
# 96    12500   30000  19971.428571
# 100   30000   30000  30000.000000
# 101   30000   30000  30000.000000
# 107   10000   30000  20000.000000
#
# [100 rows x 3 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=335394, step=1)
